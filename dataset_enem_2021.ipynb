# %%
import pandas as pd

# %%
dataset_enem = pd.read_csv(r"C:\Users\Gusta\Documents\Curso_Alura\microdados_enem_2021\DADOS\MICRODADOS_ENEM_2021.csv", encoding='latin-1', sep = ";")

# %%
dataset_enem
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
dataset_enem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210053865474    2021                5       F                1
# 1  210052384164    2021               12       M                1
# 2  210052589243    2021               13       F                3
# 3  210052128335    2021                3       M                1
# 4  210051353021    2021                2       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1                3          1
# 1            1                 1                1               11          1
# 2            1                 1                1               15          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
dataset_enem.tail(10)
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 3389822  210054424628    2021               10       F                1
# 3389823  210051676080    2021                8       M                1
# 3389824  210052788373    2021               13       F                3
# 3389825  210053818244    2021                5       F                1
# 3389826  210052408816    2021                9       F                1
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 3389822            3                 1                1                7
# ...

# %%
dataset_enem.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO',
#        'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO',
#        'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA',
#        'SG_UF_PROVA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT',
#        'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC',
#        'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN', 'TX_GABARITO_CH',
#        'TX_GABARITO_LC', 'TX_GABARITO_MT', 'TP_STATUS_REDACAO',
#        'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4',
# ...

# %%
dataset_enem["NU_INSCRICAO"]
# Out:
# 0          210053865474
# 1          210052384164
# 2          210052589243
# 3          210052128335
# 4          210051353021
#                ...
# 3389827    210053249138
# 3389828    210053776013
# 3389829    210052441508
# 3389830    210051139675
# 3389831    210052410399
# Name: NU_INSCRICAO, Length: 3389832, dtype: int64

# %%
dataset_enem["TP_SEXO"]
# Out:
# 0          F
# 1          M
# 2          F
# 3          M
# 4          F
#           ..
# 3389827    F
# 3389828    F
# 3389829    F
# 3389830    F
# 3389831    F
# Name: TP_SEXO, Length: 3389832, dtype: object

# %%
dataset_enem["TP_SEXO"].unique
# Out:
# <bound method Series.unique of 0          F
# 1          M
# 2          F
# 3          M
# 4          F
#           ..
# 3389827    F
# 3389828    F
# 3389829    F
# 3389830    F
# 3389831    F
# Name: TP_SEXO, Length: 3389832, dtype: object>

# %%
dataset_enem["TP_SEXO"].value_counts()
# Out:
# F    2090526
# M    1299306
# Name: TP_SEXO, dtype: int64

# %%
participantes_f, participantes_m = dataset_enem["TP_SEXO"].value_counts()

# %%
participantes_f
# Out:
# 2090526

# %%
participantes_m
# Out:
# 1299306

# %%
participantes_f / dataset_enem.shape[0]
# Out:
# 0.6167048986498446

# %%
participantes_m / dataset_enem.shape[0]
# Out:
# 0.38329510135015543

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.pie([participantes_f, participantes_m], labels = ["F", "M"], autopct = "%.2f%%", colors = ["yellow", "green"])
ax.set_title("Gênero dos participantes do enem 2021")
plt.show()

# %% [markdown]
# # Desafio:

# %%
# Visualize os dados somente da coluna SG_UF_PROVA e faça uma contagem para sabermos o número de participantes por estado
dataset_enem["SG_UF_PROVA"].value_counts()
# Out:
# SP    509954
# MG    327829
# BA    266194
# RJ    238347
# CE    220517
# PE    193616
# PA    185978
# RS    150484
# PR    144282
# GO    136915
# MA    127905
# PB    102002
# AM     89778
# RN     80820
# SC     80765
# PI     79969
# DF     67501
# ES     64181
# AL     56584
# MT     56085
# SE     53796
# MS     42490
# RO     32801
# TO     30873
# AP     21774
# AC     20336
# RR      8056
# Name: SG_UF_PROVA, dtype: int64

# %%
participantes_por_estado = dict(dataset_enem["SG_UF_PROVA"].value_counts())
participantes_por_estado
# Out:
# {'SP': 509954,
#  'MG': 327829,
#  'BA': 266194,
#  'RJ': 238347,
#  'CE': 220517,
#  'PE': 193616,
#  'PA': 185978,
#  'RS': 150484,
#  'PR': 144282,
#  'GO': 136915,
#  'MA': 127905,
#  'PB': 102002,
#  'AM': 89778,
#  'RN': 80820,
#  'SC': 80765,
#  'PI': 79969,
#  'DF': 67501,
#  'ES': 64181,
#  'AL': 56584,
#  'MT': 56085,
#  'SE': 53796,
#  'MS': 42490,
#  'RO': 32801,
#  'TO': 30873,
#  'AP': 21774,
#  'AC': 20336,
#  'RR': 8056}

# %%
for elemento in participantes_por_estado.items():
    print(elemento)
# Out:
# ('SP', 509954)
# ('MG', 327829)
# ('BA', 266194)
# ('RJ', 238347)
# ('CE', 220517)
# ('PE', 193616)
# ('PA', 185978)
# ('RS', 150484)
# ('PR', 144282)
# ('GO', 136915)
# ('MA', 127905)
# ('PB', 102002)
# ('AM', 89778)
# ('RN', 80820)
# ('SC', 80765)
# ('PI', 79969)
# ('DF', 67501)
# ('ES', 64181)
# ('AL', 56584)
# ('MT', 56085)
# ('SE', 53796)
# ('MS', 42490)
# ('RO', 32801)
# ('TO', 30873)
# ('AP', 21774)
# ('AC', 20336)
# ('RR', 8056)

# %%
# Faça uma plotagem da contagem de participantes por estado com a função plt.bar(). Dica: use a documentação do matplotlib.pyplot
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,12))
ax.bar(range(len(participantes_por_estado)), list(participantes_por_estado.values()), tick_label = list(participantes_por_estado.keys()), color = "purple", label = "PARTICIPANTES POR ESTADO")
plt.yticks(np.arange(0, 510000, 50000))
ax.set_title("Quantidade de participantes por estado ENEM 2021")
ax.set_ylabel("Quantidade de participantes")
ax.set_xlabel("Estados")
ax.legend()
plt.show()

# %%
# Explore outras 5 colunas.
# Use células de texto para explicar suas células de códigos.
# Compartilhe no Discord e/ou LinkedIn.

# %% [markdown]
# Analizando as colunas da base de dados

# %%
print(dataset_enem.columns)
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO',
#        'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO',
#        'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA',
#        'SG_UF_PROVA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT',
#        'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC',
#        'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN', 'TX_GABARITO_CH',
#        'TX_GABARITO_LC', 'TX_GABARITO_MT', 'TP_STATUS_REDACAO',
#        'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4',
# ...

# %% [markdown]
# Importando uma base de dados complementar
# para auxiliar no entendimento dos dados

# %%
dicionario_enem = pd.read_excel(r"C:\Users\Gusta\Documents\Curso_Alura\microdados_enem_2021\DICIONÁRIO\Dicionário_Microdados_Enem_2021.xlsx",)
dicionario_enem
# Out:
#                    DICIONÁRIO DE VARIÁVEIS - ENEM 2021             Unnamed: 1  \
# 0                                                  NaN                    NaN
# 1                                     NOME DA VARIÁVEL              Descrição
# 2                                                  NaN                    NaN
# 3                                DADOS DO PARTICIPANTE                    NaN
# 4                                         NU_INSCRICAO  Número de inscrição1
# ..                                                 ...                    ...
# 373  3. Foi considerado treineiro o inscrito que nã...                    NaN
# 374  4. As 45 primeiras posições deste campo são re...                    NaN
# 375  5. As 45 primeiras posições deste campo são re...                    NaN
# 376  6. As 45 primeiras posições deste campo são re...                    NaN
# 377  7. As 50 primeiras posições deste campo são re...                    NaN
#
# ...

# %%
# Explore outras 5 colunas.
# Use células de texto para explicar suas células de códigos.
# Compartilhe no Discord e/ou LinkedIn.

# %% [markdown]
# Escolhendo a coluna faixa etária para extrair os dados e armazenando-a em uma variável

# %%
qtd_alunos = dataset_enem["TP_FAIXA_ETARIA"].value_counts()
qtd_alunos
# Out:
# 3     699365
# 2     620784
# 4     394689
# 1     274318
# 5     250690
# 11    227574
# 6     177086
# 7     132052
# 12    130746
# 8     100580
# 13     93073
# 9      85742
# 10     71199
# 14     58754
# 15     35808
# 16     20564
# 17     10804
# 18      4102
# 19      1342
# 20       560
# Name: TP_FAIXA_ETARIA, dtype: int64

# %%
dicionario_enem.head(27)
# Out:
#    DICIONÁRIO DE VARIÁVEIS - ENEM 2021             Unnamed: 1  \
# 0                                  NaN                    NaN
# 1                     NOME DA VARIÁVEL              Descrição
# 2                                  NaN                    NaN
# 3                DADOS DO PARTICIPANTE                    NaN
# 4                         NU_INSCRICAO  Número de inscrição1
# 5                               NU_ANO            Ano do Enem
# 6                      TP_FAIXA_ETARIA          Faixa etária2
# 7                                  NaN                    NaN
# 8                                  NaN                    NaN
# 9                                  NaN                    NaN
# 10                                 NaN                    NaN
# 11                                 NaN                    NaN
# 12                                 NaN                    NaN
# 13                                 NaN                    NaN
# ...

# %% [markdown]
# Extraindo apenas as linhas importantes e armazenando em uma variável

# %%
faixa_etaria_enem = dicionario_enem.loc[6:25]
faixa_etaria_enem
# Out:
#    DICIONÁRIO DE VARIÁVEIS - ENEM 2021     Unnamed: 1 Unnamed: 2  \
# 6                      TP_FAIXA_ETARIA  Faixa etária2          1
# 7                                  NaN            NaN          2
# 8                                  NaN            NaN          3
# 9                                  NaN            NaN          4
# 10                                 NaN            NaN          5
# 11                                 NaN            NaN          6
# 12                                 NaN            NaN          7
# 13                                 NaN            NaN          8
# 14                                 NaN            NaN          9
# 15                                 NaN            NaN         10
# 16                                 NaN            NaN         11
# 17                                 NaN            NaN         12
# 18                                 NaN            NaN         13
# ...

# %% [markdown]
# Agora fazendo o drop das colunas com valores nulos e arazenando em uma variável

# %%
faixa_etaria_final = faixa_etaria_enem.dropna(axis = 'columns')
faixa_etaria_final
# Out:
#    Unnamed: 2          Unnamed: 3
# 6           1    Menor de 17 anos
# 7           2             17 anos
# 8           3             18 anos
# 9           4             19 anos
# 10          5             20 anos
# 11          6             21 anos
# 12          7             22 anos
# 13          8             23 anos
# 14          9             24 anos
# 15         10             25 anos
# 16         11  Entre 26 e 30 anos
# 17         12  Entre 31 e 35 anos
# 18         13  Entre 36 e 40 anos
# 19         14  Entre 41 e 45 anos
# 20         15  Entre 46 e 50 anos
# 21         16  Entre 51 e 55 anos
# 22         17  Entre 56 e 60 anos
# 23         18  Entre 61 e 65 anos
# 24         19  Entre 66 e 70 anos
# 25         20    Maior de 70 anos

# %% [markdown]
# Renomeando as colunas do data frame

# %%
faixa_etaria_renomeada = faixa_etaria_final.rename(columns={'Unnamed: 2':'Categoria', 'Unnamed: 3':'faixa_etaria'})

# %%
faixa_etaria_renomeada
# Out:
#    Categoria        faixa_etaria
# 6          1    Menor de 17 anos
# 7          2             17 anos
# 8          3             18 anos
# 9          4             19 anos
# 10         5             20 anos
# 11         6             21 anos
# 12         7             22 anos
# 13         8             23 anos
# 14         9             24 anos
# 15        10             25 anos
# 16        11  Entre 26 e 30 anos
# 17        12  Entre 31 e 35 anos
# 18        13  Entre 36 e 40 anos
# 19        14  Entre 41 e 45 anos
# 20        15  Entre 46 e 50 anos
# 21        16  Entre 51 e 55 anos
# 22        17  Entre 56 e 60 anos
# 23        18  Entre 61 e 65 anos
# 24        19  Entre 66 e 70 anos
# 25        20    Maior de 70 anos

# %% [markdown]
# Aplicando o merge para realizar a união dos dados da coluna faixa etária com o data frame auxiliar renomeando suas colunas

# %%
df_merge = pd.merge(faixa_etaria_renomeada, qtd_alunos_fe, left_on = 'Categoria', right_index = True)

# %%
df_merge = df_merge.rename(columns={'TP_FAIXA_ETARIA':'quantidade_alunos'})
df_merge
# Out:
#    Categoria        faixa_etaria  quantidade_alunos
# 6          1    Menor de 17 anos             274318
# 7          2             17 anos             620784
# 8          3             18 anos             699365
# 9          4             19 anos             394689
# 10         5             20 anos             250690
# 11         6             21 anos             177086
# 12         7             22 anos             132052
# 13         8             23 anos             100580
# 14         9             24 anos              85742
# 15        10             25 anos              71199
# 16        11  Entre 26 e 30 anos             227574
# 17        12  Entre 31 e 35 anos             130746
# 18        13  Entre 36 e 40 anos              93073
# 19        14  Entre 41 e 45 anos              58754
# 20        15  Entre 46 e 50 anos              35808
# 21        16  Entre 51 e 55 anos              20564
# 22        17  Entre 56 e 60 anos              10804
# ...

# %% [markdown]
# Resetando o índice do novo data frame

# %%
df_merge = df_merge.reset_index(drop=True)
df_merge
# Out:
#    Categoria        faixa_etaria  quantidade_alunos
# 0          1    Menor de 17 anos             274318
# 1          2             17 anos             620784
# 2          3             18 anos             699365
# 3          4             19 anos             394689
# 4          5             20 anos             250690
# 5          6             21 anos             177086
# 6          7             22 anos             132052
# 7          8             23 anos             100580
# 8          9             24 anos              85742
# 9         10             25 anos              71199
# 10        11  Entre 26 e 30 anos             227574
# 11        12  Entre 31 e 35 anos             130746
# 12        13  Entre 36 e 40 anos              93073
# 13        14  Entre 41 e 45 anos              58754
# 14        15  Entre 46 e 50 anos              35808
# 15        16  Entre 51 e 55 anos              20564
# 16        17  Entre 56 e 60 anos              10804
# ...

# %% [markdown]
# Realizando o plot do gráfico "Quantidade de participantes por faixa etária"

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.bar(range(len(df_merge['faixa_etaria'])), list(df_merge['quantidade_alunos']), width=0.6, tick_label = list(df_merge['faixa_etaria']), color = "red", label = "PARTICIPANTES POR FAIXA ETÁRIA")
plt.yticks(np.arange(0, 800000, 50000))
plt.xticks(range(len(df_merge['faixa_etaria'])), rotation='vertical')
ax.set_title("Quantidade de participantes por faixa etária ENEM 2021", fontsize=14, color = 'red')
ax.set_ylabel("Quantidade de participantes", fontsize=14, color = 'red')
ax.set_xlabel("Faixas etárias", fontsize=14, color = 'red')
ax.legend()
plt.show()

# %% [markdown]
# Utilizando a coluna estado civil da base de dados

# %%
estado_civil_count = dataset_enem["TP_ESTADO_CIVIL"].value_counts()
estado_civil_count
# Out:
# 1    2995915
# 2     196285
# 0     139630
# 3      54141
# 4       3861
# Name: TP_ESTADO_CIVIL, dtype: int64

# %%
estado_civil = dicionario_enem.loc[28:32]
estado_civil
# Out:
#    DICIONÁRIO DE VARIÁVEIS - ENEM 2021    Unnamed: 1 Unnamed: 2  \
# 28                     TP_ESTADO_CIVIL  Estado Civil          0
# 29                                 NaN           NaN          1
# 30                                 NaN           NaN          2
# 31                                 NaN           NaN          3
# 32                                 NaN           NaN          4
#
#                                  Unnamed: 3 Unnamed: 4 Unnamed: 5
# 28                            Não informado          1   Numérica
# 29                              Solteiro(a)        NaN        NaN
# 30        Casado(a)/Mora com companheiro(a)        NaN        NaN
# 31  Divorciado(a)/Desquitado(a)/Separado(a)        NaN        NaN
# 32                                 Viúvo(a)        NaN        NaN

# %%
estado_civil = estado_civil.dropna(axis = 'columns')
estado_civil
# Out:
#    Unnamed: 2                               Unnamed: 3
# 28          0                            Não informado
# 29          1                              Solteiro(a)
# 30          2        Casado(a)/Mora com companheiro(a)
# 31          3  Divorciado(a)/Desquitado(a)/Separado(a)
# 32          4                                 Viúvo(a)

# %%
estado_civil = estado_civil.rename(columns = {'Unnamed: 2':'categoria', 'Unnamed: 3':'estado_civil'})
estado_civil
# Out:
#    categoria                             estado_civil
# 28         0                            Não informado
# 29         1                              Solteiro(a)
# 30         2        Casado(a)/Mora com companheiro(a)
# 31         3  Divorciado(a)/Desquitado(a)/Separado(a)
# 32         4                                 Viúvo(a)

# %%
dataset_estado_civil = pd.merge(estado_civil, estado_civil_count, left_on = 'categoria', right_index = True)
dataset_estado_civil
# Out:
#    categoria                             estado_civil  TP_ESTADO_CIVIL
# 28         0                            Não informado           139630
# 29         1                              Solteiro(a)          2995915
# 30         2        Casado(a)/Mora com companheiro(a)           196285
# 31         3  Divorciado(a)/Desquitado(a)/Separado(a)            54141
# 32         4                                 Viúvo(a)             3861

# %%
dataset_estado_civil = dataset_estado_civil.rename(columns={'TP_ESTADO_CIVIL':'Quantidade'})
dataset_estado_civil
# Out:
#    categoria                             estado_civil  Quantidade
# 28         0                            Não informado      139630
# 29         1                              Solteiro(a)     2995915
# 30         2        Casado(a)/Mora com companheiro(a)      196285
# 31         3  Divorciado(a)/Desquitado(a)/Separado(a)       54141
# 32         4                                 Viúvo(a)        3861

# %%
dataset_estado_civil = dataset_estado_civil.reset_index(drop=True)
dataset_estado_civil
# Out:
#   categoria                             estado_civil  Quantidade
# 0         0                            Não informado      139630
# 1         1                              Solteiro(a)     2995915
# 2         2        Casado(a)/Mora com companheiro(a)      196285
# 3         3  Divorciado(a)/Desquitado(a)/Separado(a)       54141
# 4         4                                 Viúvo(a)        3861

# %%
fig, ax = plt.subplots(figsize=(6,15))
ax.bar(range(len(dataset_estado_civil['estado_civil'])), list(dataset_estado_civil['Quantidade']), width=0.6, tick_label = list(dataset_estado_civil['estado_civil']), color = "green", label = "PARTICIPANTES POR ESTADO CIVIL")
plt.yticks(np.arange(0, 3000000, 50000))
plt.xticks(range(len(dataset_estado_civil['estado_civil'])), rotation='vertical')
ax.set_title("Quantidade de participantes por estado civil ENEM 2021", fontsize=14, color = 'green')
ax.set_ylabel("Quantidade de participantes", fontsize=14, color = 'green')
ax.set_xlabel("Estado civil", fontsize=14, color = 'green')
ax.legend()
plt.show()
